# %% [markdown]
# ### Forward Propogation
# ![image.png](attachment:image.png)
#
# ### Backpropagation
# Uses partial derivatives to calculate the gradient of each neural network parameter.
#
# ![image-2.png](attachment:image-2.png)
